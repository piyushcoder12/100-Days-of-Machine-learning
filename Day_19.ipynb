# %% [markdown]
# <a href="https://colab.research.google.com/github/piyushcoder12/100-Days-of-Machine-learning/blob/main/Day_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/chess.csv.zip') # chess dataset

# %% [markdown]
# 1. How big is the data?

# %%
df.shape
# Out:
# (62560, 8)

# %% [markdown]
# 2. How doe sthe data look like?

# %%
df.sample(10)
# Out:
#       rank                         name title country rating games b_year  \
# 53443   84        Morozevich, Alexander     g     RUS   2659     0   1977
# 4534     5                  Leko, Peter     g     HUN   2738    27   1979
# 52954   95                 Tarini Goyal    wf     IND   2164     0   2001
# 39470   11              Dzagnidze, Nana     g     GEO   2519    11   1987
# 56547   88             Priyanka Nutakki    wm     IND   2187    16   2002
# 40508   49          Goltseva, Ekaterina    wf     RUS   2260     0   2002
# 32868    9                   Ni, Shiqun    wg     CHN   2377     2   1997
# 59206   47           Matviishen, Viktor     m     UKR   2496     9   2002
# 38468    9  Nomin-Erdene, Davaademberel     m     MGL   2365    18   2000
# 5909    50             Nikolic, Predrag     g     BIH   2665    21   1960
#
#                             p_title
# 53443    Top 100 Players April 2021
# 4534     Top 100 Players April 2006
# 52954   Top 100 Girls February 2021
# ...

# %% [markdown]
# 3. What is the data type of cols>?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62560 entries, 0 to 62559
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   rank     62560 non-null  object
#  1   name     62560 non-null  object
#  2   title    60751 non-null  object
#  3   country  62560 non-null  object
#  4   rating   62560 non-null  object
#  5   games    62560 non-null  object
#  6   b_year   62560 non-null  object
#  7   p_title  62560 non-null  object
# dtypes: object(8)
# memory usage: 3.8+ MB

# %% [markdown]
# 4. Are there any missing values?

# %%
df.isnull().sum()
# Out:
# rank          0
# name          0
# title      1809
# country       0
# rating        0
# games         0
# b_year        0
# p_title       0
# dtype: int64

# %% [markdown]
# 5. How does the data look mathematically?

# %%
df.describe()
# Out:
#          rank          name  title country        rating  games b_year  \
# count   62560         62560  60751   62560         62560  62560  62560
# unique    101          1750      9      89           771     78     68
# top        18  MISSING_DATA      g     RUS  MISSING_DATA      0   2000
# freq      726           460  28500   11701           460  25087   3374
#
#                           p_title
# count                       62560
# unique                        728
# top     Top 100 Players July 2000
# freq                          100

# %% [markdown]
# 6. Are there duplicate values?

# %%
df.duplicated().sum()
# Out:
# 455

# %% [markdown]
# 7. How is the correlation between cols?

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-2f6f6606aa2c> in <cell line: 1>()
# ----> 1 df.corr()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839         if result.dtype is not dtype:
#    1840             result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %% [markdown]
# # 2 dataset are understand

# %%
df = pd.read_csv('/content/NFLX.csv') # netflix stock prediction

# %%
df.shape
# Out:
# (1009, 7)

# %%
df.sample(5)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 92   2018-06-18  387.720001  393.160004  386.500000  390.399994  390.399994
# 101  2018-06-29  399.190002  401.329987  390.549988  391.429993  391.429993
# 322  2019-05-17  356.390015  359.619995  353.790009  354.450012  354.450012
# 117  2018-07-24  366.940002  367.399994  354.559998  357.320007  357.320007
# 653  2020-09-09  519.210022  520.000000  492.570007  500.190002  500.190002
#
#        Volume
# 92    6824800
# 101   9252500
# 322   4725400
# 117  12851500
# 653   6848100

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1009 non-null   object
#  1   Open       1009 non-null   float64
#  2   High       1009 non-null   float64
#  3   Low        1009 non-null   float64
#  4   Close      1009 non-null   float64
#  5   Adj Close  1009 non-null   float64
#  6   Volume     1009 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 55.3+ KB

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1009.000000  1009.000000  1009.000000  1009.000000  1009.000000
# mean    419.059673   425.320703   412.374044   419.000733   419.000733
# std     108.537532   109.262960   107.555867   108.289999   108.289999
# min     233.919998   250.649994   231.229996   233.880005   233.880005
# 25%     331.489990   336.299988   326.000000   331.619995   331.619995
# 50%     377.769989   383.010010   370.880005   378.670013   378.670013
# 75%     509.130005   515.630005   502.529999   509.079987   509.079987
# max     692.349976   700.989990   686.090027   691.690002   691.690002
#
#              Volume
# count  1.009000e+03
# mean   7.570685e+06
# std    5.465535e+06
# min    1.144000e+06
# 25%    4.091900e+06
# 50%    5.934500e+06
# 75%    9.322400e+06
# max    5.890430e+07

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
df.corr()['Pclass']
# Out:
# PassengerId   -0.035144
# Survived      -0.338481
# Pclass         1.000000
# Age           -0.369226
# SibSp          0.083081
# Parch          0.018443
# Fare          -0.549500
# Name: Pclass, dtype: float64

# %% [markdown]
# 3 train titanic dataset understand

# %%
df= pd.read_csv('/content/train.csv')

# %%
df.shape
# Out:
# (891, 12)

# %%
df.sample(7)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 455          456         1       3                         Jalsevac, Mr. Ivan
# 886          887         0       2                      Montvila, Rev. Juozas
# 51            52         0       3               Nosworthy, Mr. Richard Cater
# 403          404         0       3             Hakkarainen, Mr. Pekka Pietari
# 144          145         0       2                 Andrew, Mr. Edgardo Samuel
# 430          431         1       1  Bjornstrom-Steffansson, Mr. Mauritz Hakan
# 226          227         1       2                  Mellors, Mr. William John
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 455  male  29.0      0      0            349240   7.8958   NaN        C
# 886  male  27.0      0      0            211536  13.0000   NaN        S
# 51   male  21.0      0      0        A/4. 39886   7.8000   NaN        S
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %% [markdown]
# 3.Dataset Ubnderstand

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/games.csv.zip')

# %%
# 1  . how big the data
df.shape
# Out:
# (20058, 16)

# %%
#2. how does the data look like
df.head()
df.sample(20034)
# Out:
#              id  rated    created_at  last_move_at  turns victory_status  \
# 9056   vPmUfx98   True  1.489970e+12  1.489970e+12     84         resign
# 19276  iaiENhPo   True  1.502003e+12  1.502003e+12     23           mate
# 14559  pylapHm1   True  1.496166e+12  1.496167e+12    140           draw
# 16221  ilal9hC5   True  1.500213e+12  1.500214e+12     80           mate
# 11643  F34kNloy  False  1.503161e+12  1.503162e+12     86         resign
# ...         ...    ...           ...           ...    ...            ...
# 798    TpzoFNxO   True  1.503350e+12  1.503350e+12     80         resign
# 18787  1kfWeKNj  False  1.449268e+12  1.449269e+12     61      outoftime
# 18094  HY6Nkd7w   True  1.496352e+12  1.496352e+12     65         resign
# 18034  r3JGOUHc   True  1.464711e+12  1.464713e+12    111         resign
# 6597   b1Z5y5jh   True  1.460120e+12  1.460120e+12     82         resign
#
#       winner increment_code         white_id  white_rating       black_id  \
# ...

# %%
# 3.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20058 entries, 0 to 20057
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              20058 non-null  object
#  1   rated           20058 non-null  bool
#  2   created_at      20058 non-null  float64
#  3   last_move_at    20058 non-null  float64
#  4   turns           20058 non-null  int64
#  5   victory_status  20058 non-null  object
#  6   winner          20058 non-null  object
#  7   increment_code  20058 non-null  object
#  8   white_id        20058 non-null  object
#  9   white_rating    20058 non-null  int64
#  10  black_id        20058 non-null  object
#  11  black_rating    20058 non-null  int64
#  12  moves           20058 non-null  object
#  13  opening_eco     20058 non-null  object
#  14  opening_name    20058 non-null  object
#  15  opening_ply     20058 non-null  int64
# dtypes: bool(1), float64(2), int64(4), object(9)
# ...

# %%
#4. Are there any missing values?
df.isnull().sum()
# Out:
# id                0
# rated             0
# created_at        0
# last_move_at      0
# turns             0
# victory_status    0
# winner            0
# increment_code    0
# white_id          0
# white_rating      0
# black_id          0
# black_rating      0
# moves             0
# opening_eco       0
# opening_name      0
# opening_ply       0
# dtype: int64

# %%
#5. How does the data look mathematically
df.describe()
# Out:
#          created_at  last_move_at         turns  white_rating  black_rating  \
# count  2.005800e+04  2.005800e+04  20058.000000  20058.000000  20058.000000
# mean   1.483617e+12  1.483618e+12     60.465999   1596.631868   1588.831987
# std    2.850151e+10  2.850140e+10     33.570585    291.253376    291.036126
# min    1.376772e+12  1.376772e+12      1.000000    784.000000    789.000000
# 25%    1.477548e+12  1.477548e+12     37.000000   1398.000000   1391.000000
# 50%    1.496010e+12  1.496010e+12     55.000000   1567.000000   1562.000000
# 75%    1.503170e+12  1.503170e+12     79.000000   1793.000000   1784.000000
# max    1.504493e+12  1.504494e+12    349.000000   2700.000000   2723.000000
#
#         opening_ply
# count  20058.000000
# mean       4.816981
# std        2.797152
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        6.000000
# max       28.000000

# %%
#6. Are there duplicate values?
df.duplicated().sum()
# Out:
# 429

# %%
# Drop all duplicate rows
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum() # remove all the duplicated data values
# Out:
# 0

# %%
df.dtypes
# Out:
# id                 object
# rated                bool
# created_at        float64
# last_move_at      float64
# turns               int64
# victory_status     object
# winner             object
# increment_code     object
# white_id           object
# white_rating        int64
# black_id           object
# black_rating        int64
# moves              object
# opening_eco        object
# opening_name       object
# opening_ply         int64
# dtype: object

# %%
#7. how is the correlation between Cols
# means ek items ke increase or decrease se another item pr kya changes ho raha h
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-91d03b602258> in <cell line: 3>()
#       1 #7. how is the correlation between Cols
#       2 # means ek items ke increase or decrease se another item pr kya changes ho raha h
# ----> 3 df.corr()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...
