# %% [markdown]
# <a href="https://colab.research.google.com/github/piyushcoder12/100-Days-of-Machine-learning/blob/main/Day_17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# API Fetch

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
temp_df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Framed in the 1940s for the double murder of h...   1994-09-23     128.873
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     138.085
# 2  In the continuing saga of the Corleone crime f...   1974-12-20      97.561
# 3  The true story of how businessman Oskar Schind...   1993-12-15      87.458
# 4  The defense and the prosecution have rested an...   1957-04-10      61.191
#
#    vote_average  vote_count
# 0         8.704       25986
# 1         8.695       19706
# 2         8.577       11904
# 3         8.567       15301
# 4         8.542        8184

# %%
df = pd.DataFrame()

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    temp_df = pd.concat([temp_df, temp_df], ignore_index=True)

# %%
temp_df
# Out:
#         id                              title  \
# 0   277685                         Unfriended
# 1   195590                            Collide
# 2     9586        The Bonfire of the Vanities
# 3    22949                           Old Dogs
# 4    11804                        White Noise
# 5     6519               The Dukes of Hazzard
# 6       83                         Open Water
# 7   641790                      Trauma Center
# 8   101179                      Truth or Dare
# 9    13160                 Over Her Dead Body
# 10   17350                      The Brice Man
# 11   77234                The Numbers Station
# 12   76649                            Pompeii
# 13  581644                        The Misfits
# 14   77663                     Killing Season
# 15  301846                               Howl
# 16    7839                       Wedding Daze
# 17  150117                   I Give It a Year
# 18   97430        The Man with the Iron Fists
# ...

# %%
temp_df.shape
# Out:
# (40, 7)

# %%
temp_df.to_csv('movies.csv')
